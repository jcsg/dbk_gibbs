# %%
# Python 3.5
from collections import defaultdict as dd

# %%
# In the main program, you'll need to take an alignment file, 
# process it line by line, and make each line into a dictionary
# with the second index (English) as keys and the first index (foreign)
# as values. Because we're doing morphologically complex languages
# to English, we want to extract English phrases, since a phrase
# could just be a word in the morphologically complex language.

# %%
def create_align_dict(line):
    """
    Takes a string, called "line", which is a line from the output of the Berkeley aligner, e.g.
    "0-2 1-0 2-0 3-1 4-1 5-3 6-3 7-4 8-6 9-5 10-7 11-9 12-8 12-10 13-11 13-12 14-14 15-13 16-13 17-15 18-17 18-18 19-19 19-20 19-21 19-22 19-23 20-24 21-25 22-26 23-26 24-27"
    We strip any trailing newline/return characters, split the line on whitespace, then create
    a dictionary object, align_dict, in which the second index (English) is the key and the first
    index (foreign) is a value.
    """
    align_dict = dd(set)
    line = line.strip("\n\r")
    pairs = line.split()
    for i in pairs:
        index = i.split("-")
        align_dict[int(index[1])].add(int(index[0]))
    
    return align_dict

# %%
def find_phrases(align_dict):
    """
    This function is based on the pseudocode presented in section 5.2.3 
    of the 2012 edition of Philipp Koehn's book "Statistical Machine Translation."
    
    align_dict should be a dictionary object in which the keys are indices
    to English words while the values are indices to foreign words.
    
    Borrowed some bugfixes and design from:
    http://stackoverflow.com/questions/25109001/phrase-extraction-algorithm-for-statistical-machine-translation
    """
    def extract(f_start,f_end,e_start,e_end):
        """
        docstring
        """
#        if f_end < 0:
#            return set()
#        for e in range(e_start,e_end+1):
#            for f in sorted(align_dict[e]):
#                if f >= f_start and f <= f_end and (e < e_start or e > e_end):
#                    return set()
#        phrase_pairs = set()
#        f_s = f_start
#        f_e = f_end
#        for f_e in range(f_end, f_start):
#            for f_s in range(f_start, f_end):
#                phrase_pairs.add((e_start,e_end,f_s,f_e))
#                f_e += 1
#            f_s -= 1
#            
#        return phrase_pairs

# Code from:
# http://stackoverflow.com/questions/25109001/phrase-extraction-algorithm-for-statistical-machine-translation

        if f_end < 0:  # 0-based indexing.
            return set()
        # Check if alignement points are consistent.
        for e in align_dict:
            for f in sorted(align_dict[e]):
                if ((f_start <= f <= f_end) and (e < e_start or e > e_end)):
                    return set()

        # Add phrase pairs (incl. additional unaligned f)
        # Remark:  how to interpret "additional unaligned f"?
        phrases = set()
        f_s = f_start
        # repeat-
        while True:
            f_e = f_end
            # repeat-
            while True:
                # add phrase pair ([e_start, e_end], [fs, fe]) to set E
                # Need to +1 in range  to include the end-point.
                #src_phrase = " ".join(srctext[i] for i in range(e_start,e_end+1))
                #trg_phrase = " ".join(trgtext[i] for i in range(fs,fe+1))
                # Include more data for later ordering.
                phrases.add((e_start,e_end,f_s,f_e))
                f_e += 1 # fe++
                # -until fe aligned or out-of-bounds
                if f_e in f_aligned or f_e == e_max:
                    break
            f_s -=1  # fs--
            # -until fs aligned or out-of- bounds
            if f_s in f_aligned or f_s < 0:
                break
        return phrases
    
    bp = set()
    e_max = (sorted(align_dict.keys())[-1])#+1
    e_aligned = set(align_dict.keys())
    f_aligned = set()
    for e in align_dict:
        for f in align_dict[e]:
            f_aligned.add(f)
    f_max = (sorted(f_aligned)[-1])+1
    
    for e_start in range(e_max):
        for e_end in range(e_start,e_max):
            f_start = f_max-1
            f_end = -1
            for e in align_dict:
                for f in sorted(align_dict[e]):
                    if e_start <= e <= e_end:
                        f_start = min(f,f_start)
                        f_end = max(f,f_end)
            if extract(f_start,f_end,e_start,e_end) != set():
                for pair in extract(f_start,f_end,e_start,e_end):   # deal with extract = set()!
                    bp.add(pair)
    
    return bp

# %%
def print_phrases(phrase_set,src,trg):
    """
    Take a source sentence and an aligned target sentence.
    """
    src_list = src.split()
    trg_list = trg.split()
    print(len(src_list),src_list)
    print(len(trg_list),trg_list)
    src_dict = {}
    trg_dict = {}
    for i, word in enumerate(src_list):
        src_dict[i] = word
    for i, word in enumerate(trg_list):
        trg_dict[i] = word
    for phrase in sorted(phrase_set):
        print(" ".join([trg_dict[elem] for elem in range(phrase[0],phrase[1]+1)]))
        print(" ".join([src_dict[elem] for elem in range(phrase[2],phrase[3]+1)]))

# %%
src = "José , su marido , que era un hombre justo y no quería denunciar públicamente a María , decidió separarse de ella en secreto ."
trg = "Her husband Joseph was an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with her secretly ."
line = "0-2 1-0 2-0 3-1 4-1 5-3 6-3 7-4 8-6 9-5 10-7 11-9 12-8 12-10 13-11 13-12 14-14 15-13 16-13 17-15 18-17 18-18 19-19 19-20 19-21 19-22 19-23 20-24 21-25 22-26 23-26 24-27"
align_dict = create_align_dict(line)
phrase_set = find_phrases(align_dict)
print_phrases(phrase_set,src,trg)
# Out:
# 25 ['José', ',', 'su', 'marido', ',', 'que', 'era', 'un', 'hombre', 'justo', 'y', 'no', 'quería', 'denunciar', 'públicamente', 'a', 'María', ',', 'decidió', 'separarse', 'de', 'ella', 'en', 'secreto', '.']
# 28 ['Her', 'husband', 'Joseph', 'was', 'an', 'honorable', 'man', 'and', 'did', 'not', 'want', 'to', 'disgrace', 'her', 'publicly', '.', 'So', 'he', 'decided', 'to', 'break', 'the', 'marriage', 'agreement', 'with', 'her', 'secretly', '.']
# Her
# , su
# Her husband
# , su marido ,
# Her husband Joseph
# José , su marido ,
# Her husband Joseph was
# José , su marido , que era
# Her husband Joseph was an
# José , su marido , que era un
# Her husband Joseph was an honorable man
# José , su marido , que era un hombre justo
# Her husband Joseph was an honorable man and
# José , su marido , que era un hombre justo y
# Her husband Joseph was an honorable man and did not want
# José , su marido , que era un hombre justo y no quería
# Her husband Joseph was an honorable man and did not want to disgrace
# José , su marido , que era un hombre justo y no quería denunciar
# Her husband Joseph was an honorable man and did not want to disgrace her publicly
# José , su marido , que era un hombre justo y no quería denunciar públicamente a María
# Her husband Joseph was an honorable man and did not want to disgrace her publicly .
# José , su marido , que era un hombre justo y no quería denunciar públicamente a María ,
# Her husband Joseph was an honorable man and did not want to disgrace her publicly . So
# José , su marido , que era un hombre justo y no quería denunciar públicamente a María ,
# Her husband Joseph was an honorable man and did not want to disgrace her publicly . So he decided
# José , su marido , que era un hombre justo y no quería denunciar públicamente a María , decidió
# Her husband Joseph was an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement
# José , su marido , que era un hombre justo y no quería denunciar públicamente a María , decidió separarse
# Her husband Joseph was an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with
# José , su marido , que era un hombre justo y no quería denunciar públicamente a María , decidió separarse de
# Her husband Joseph was an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with her
# José , su marido , que era un hombre justo y no quería denunciar públicamente a María , decidió separarse de ella
# Her husband Joseph was an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with her secretly
# José , su marido , que era un hombre justo y no quería denunciar públicamente a María , decidió separarse de ella en secreto
# husband
# marido ,
# Joseph
# José
# was
# que era
# was an
# que era un
# was an honorable man
# que era un hombre justo
# was an honorable man and
# que era un hombre justo y
# was an honorable man and did not want
# que era un hombre justo y no quería
# was an honorable man and did not want to disgrace
# que era un hombre justo y no quería denunciar
# was an honorable man and did not want to disgrace her publicly
# que era un hombre justo y no quería denunciar públicamente a María
# was an honorable man and did not want to disgrace her publicly .
# que era un hombre justo y no quería denunciar públicamente a María ,
# was an honorable man and did not want to disgrace her publicly . So
# que era un hombre justo y no quería denunciar públicamente a María ,
# was an honorable man and did not want to disgrace her publicly . So he decided
# que era un hombre justo y no quería denunciar públicamente a María , decidió
# was an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement
# que era un hombre justo y no quería denunciar públicamente a María , decidió separarse
# was an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with
# que era un hombre justo y no quería denunciar públicamente a María , decidió separarse de
# was an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with her
# que era un hombre justo y no quería denunciar públicamente a María , decidió separarse de ella
# was an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with her secretly
# que era un hombre justo y no quería denunciar públicamente a María , decidió separarse de ella en secreto
# an
# un
# an honorable man
# un hombre justo
# an honorable man and
# un hombre justo y
# an honorable man and did not want
# un hombre justo y no quería
# an honorable man and did not want to disgrace
# un hombre justo y no quería denunciar
# an honorable man and did not want to disgrace her publicly
# un hombre justo y no quería denunciar públicamente a María
# an honorable man and did not want to disgrace her publicly .
# un hombre justo y no quería denunciar públicamente a María ,
# an honorable man and did not want to disgrace her publicly . So
# un hombre justo y no quería denunciar públicamente a María ,
# an honorable man and did not want to disgrace her publicly . So he decided
# un hombre justo y no quería denunciar públicamente a María , decidió
# an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement
# un hombre justo y no quería denunciar públicamente a María , decidió separarse
# an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with
# un hombre justo y no quería denunciar públicamente a María , decidió separarse de
# an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with her
# un hombre justo y no quería denunciar públicamente a María , decidió separarse de ella
# an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with her secretly
# un hombre justo y no quería denunciar públicamente a María , decidió separarse de ella en secreto
# honorable
# justo
# honorable man
# hombre justo
# honorable man and
# hombre justo y
# honorable man and did not want
# hombre justo y no quería
# honorable man and did not want to disgrace
# hombre justo y no quería denunciar
# honorable man and did not want to disgrace her publicly
# hombre justo y no quería denunciar públicamente a María
# honorable man and did not want to disgrace her publicly .
# hombre justo y no quería denunciar públicamente a María ,
# honorable man and did not want to disgrace her publicly . So
# hombre justo y no quería denunciar públicamente a María ,
# honorable man and did not want to disgrace her publicly . So he decided
# hombre justo y no quería denunciar públicamente a María , decidió
# honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement
# hombre justo y no quería denunciar públicamente a María , decidió separarse
# honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with
# hombre justo y no quería denunciar públicamente a María , decidió separarse de
# honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with her
# hombre justo y no quería denunciar públicamente a María , decidió separarse de ella
# honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with her secretly
# hombre justo y no quería denunciar públicamente a María , decidió separarse de ella en secreto
# man
# hombre
# and
# y
# and did not want
# y no quería
# and did not want to disgrace
# y no quería denunciar
# and did not want to disgrace her publicly
# y no quería denunciar públicamente a María
# and did not want to disgrace her publicly .
# y no quería denunciar públicamente a María ,
# and did not want to disgrace her publicly . So
# y no quería denunciar públicamente a María ,
# and did not want to disgrace her publicly . So he decided
# y no quería denunciar públicamente a María , decidió
# and did not want to disgrace her publicly . So he decided to break the marriage agreement
# y no quería denunciar públicamente a María , decidió separarse
# and did not want to disgrace her publicly . So he decided to break the marriage agreement with
# y no quería denunciar públicamente a María , decidió separarse de
# and did not want to disgrace her publicly . So he decided to break the marriage agreement with her
# y no quería denunciar públicamente a María , decidió separarse de ella
# and did not want to disgrace her publicly . So he decided to break the marriage agreement with her secretly
# y no quería denunciar públicamente a María , decidió separarse de ella en secreto
# did not want
# no quería
# did not want to disgrace
# no quería denunciar
# did not want to disgrace her publicly
# no quería denunciar públicamente a María
# did not want to disgrace her publicly .
# no quería denunciar públicamente a María ,
# did not want to disgrace her publicly . So
# no quería denunciar públicamente a María ,
# did not want to disgrace her publicly . So he decided
# no quería denunciar públicamente a María , decidió
# did not want to disgrace her publicly . So he decided to break the marriage agreement
# no quería denunciar públicamente a María , decidió separarse
# did not want to disgrace her publicly . So he decided to break the marriage agreement with
# no quería denunciar públicamente a María , decidió separarse de
# did not want to disgrace her publicly . So he decided to break the marriage agreement with her
# no quería denunciar públicamente a María , decidió separarse de ella
# did not want to disgrace her publicly . So he decided to break the marriage agreement with her secretly
# no quería denunciar públicamente a María , decidió separarse de ella en secreto
# not
# no
# to disgrace
# denunciar
# to disgrace her publicly
# denunciar públicamente a María
# to disgrace her publicly .
# denunciar públicamente a María ,
# to disgrace her publicly . So
# denunciar públicamente a María ,
# to disgrace her publicly . So he decided
# denunciar públicamente a María , decidió
# to disgrace her publicly . So he decided to break the marriage agreement
# denunciar públicamente a María , decidió separarse
# to disgrace her publicly . So he decided to break the marriage agreement with
# denunciar públicamente a María , decidió separarse de
# to disgrace her publicly . So he decided to break the marriage agreement with her
# denunciar públicamente a María , decidió separarse de ella
# to disgrace her publicly . So he decided to break the marriage agreement with her secretly
# denunciar públicamente a María , decidió separarse de ella en secreto
# her
# a María
# her publicly
# públicamente a María
# her publicly .
# públicamente a María ,
# her publicly . So
# públicamente a María ,
# her publicly . So he decided
# públicamente a María , decidió
# her publicly . So he decided to break the marriage agreement
# públicamente a María , decidió separarse
# her publicly . So he decided to break the marriage agreement with
# públicamente a María , decidió separarse de
# her publicly . So he decided to break the marriage agreement with her
# públicamente a María , decidió separarse de ella
# her publicly . So he decided to break the marriage agreement with her secretly
# públicamente a María , decidió separarse de ella en secreto
# publicly
# públicamente
# .
# ,
# . So
# ,
# . So he decided
# , decidió
# . So he decided to break the marriage agreement
# , decidió separarse
# . So he decided to break the marriage agreement with
# , decidió separarse de
# . So he decided to break the marriage agreement with her
# , decidió separarse de ella
# . So he decided to break the marriage agreement with her secretly
# , decidió separarse de ella en secreto
# So he decided
# decidió
# So he decided to break the marriage agreement
# decidió separarse
# So he decided to break the marriage agreement with
# decidió separarse de
# So he decided to break the marriage agreement with her
# decidió separarse de ella
# So he decided to break the marriage agreement with her secretly
# decidió separarse de ella en secreto
# he decided
# decidió
# he decided to break the marriage agreement
# decidió separarse
# he decided to break the marriage agreement with
# decidió separarse de
# he decided to break the marriage agreement with her
# decidió separarse de ella
# he decided to break the marriage agreement with her secretly
# decidió separarse de ella en secreto
# to break the marriage agreement
# separarse
# to break the marriage agreement with
# separarse de
# to break the marriage agreement with her
# separarse de ella
# to break the marriage agreement with her secretly
# separarse de ella en secreto
# with
# de
# with her
# de ella
# with her secretly
# de ella en secreto
# her
# ella
# her secretly
# ella en secreto
# secretly
# en secreto

# %%
# THIS CODE NEVER TERMINATES!!! What's wrong??

src = "Michael geht davon aus , dass er im haus bleibt"
trg = "Michael assumes that he will stay in the house"
line = "0-0 1-1 2-1 3-1 5-2 6-3 7-6 7-7 8-8 9-4 9-5"
align_dict = create_align_dict(line)
phrase_set = find_phrases(align_dict)

#print_phrases(phrase_set,src,trg)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a3281e4d89c5> in <module>()
#       3 line = "0-0 1-1 2-1 3-1 5-2 6-3 7-6 7-7 8-8 9-4 9-5"
#       4 align_dict = create_align_dict(line)
# ----> 5 phrase_set = find_phrases(align_dict)
#       6 #print_phrases(phrase_set,src,trg)
#
# <ipython-input-4-64ba562395dc> in find_phrases(align_dict)
#      85                         f_start = min(f,f_start)
#      86                         f_end = max(f,f_end)
# ---> 87             if extract(f_start,f_end,e_start,e_end) != set():
#      88                 for pair in extract(f_start,f_end,e_start,e_end):   # deal with extract = set()!
#      89                     bp.add(pair)
#
# <ipython-input-4-64ba562395dc> in extract(f_start, f_end, e_start, e_end)
#      56                 #trg_phrase = " ".join(trgtext[i] for i in range(fs,fe+1))
#      57                 # Include more data for later ordering.
# ---> 58                 phrases.add((e_start,e_end,f_s,f_e))
#      59                 f_e += 1 # fe++
#      60                 # -until fe aligned or out-of-bounds
#
# KeyboardInterrupt:

# %%
src = "José , su marido , que era un hombre justo y no quería denunciar públicamente a María , decidió separarse de ella en secreto ."
trg = "Her husband Joseph was an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with her secretly ."
line = "0-2 1-0 2-0 3-1 4-1 5-3 6-3 7-4 8-6 9-5 10-7 11-9 12-8 12-10 13-11 13-12 14-14 15-13 16-13 17-15 18-17 18-18 19-19 19-20 19-21 19-22 19-23 20-24 21-25 22-26 23-26 24-27"
align_dict = create_align_dict(line)

# %%
def phrase_extraction(srctext, trgtext, line):
    """
    Phrase extraction algorithm.
    """
    def extract(f_start, f_end, e_start, e_end):
        if f_end < 0:  # 0-based indexing.
            return {}
        # Check if alignment points are consistent.
        for e,f in alignment:
            if ((f_start <= f <= f_end) and
               (e < e_start or e > e_end)):
                return {}

        # Add phrase pairs (incl. additional unaligned f)
        # Remark:  how to interpret "additional unaligned f"?
        phrases = set()
        fs = f_start
        while True:
            fe = f_end
            while True:
                # add phrase pair ([e_start, e_end], [fs, fe]) to set E
                # Need to +1 in range  to include the endpoint.
                src_phrase = " ".join(srctext[i] for i in range(e_start,e_end+1))
                trg_phrase = " ".join(trgtext[i] for i in range(fs,fe+1))
                # Include more data for later ordering.
                phrases.add(((e_start, e_end+1), src_phrase, trg_phrase))
                fe += 1 # fe++
                # -until fe aligned or out-of-bounds
                if fe in f_aligned or fe == trglen:
                    break
            fs -=1  # fe--
            # -until fs aligned or out-of-bounds
            if fs in f_aligned or fs < 0:
                break
        return phrases

    # Calculate no. of tokens in source and target texts.
    srctext = srctext.split()   # e
    trgtext = trgtext.split()   # f
    srclen = len(srctext)       # len(e)
    trglen = len(trgtext)       # len(f)
    # Keeps an index of which source/target words are aligned.
    f_aligned = set()
    e_aligned = set()
    lst = line.split()
    alignment = list()
    for pair in line_lst:
        [f, e] = pair.split("-")
        f_aligned.add(int(f))
        e_aligned.add(int(e))
        alignment.append((int(f),int(e)))
#    e_aligned = [i for i,_ in alignment]
#    f_aligned = [j for _,j in alignment]

    bp = set() # set of phrase pairs BP
    # for e start = 1 ... length(e) do
    # Index e_start from 0 to len(e) - 1
    for e_start in range(srclen):
        # for e end = e start ... length(e) do
        # Index e_end from e_start to len(e) - 1
        for e_end in range(e_start, srclen):
            # // find the minimally matching foreign phrase
            # (f start , f end ) = ( length(f), 0 )
            # f_start ∈ [0, len(f) - 1]; f_end ∈ [0, len(f) - 1]
            f_start, f_end = trglen-1 , -1  #  0-based indexing
            # for all (e,f) ∈ A do
            for e,f in alignment:
                # if e start ≤ e ≤ e end then
                if e_start <= e <= e_end:
                    f_start = min(f, f_start)
                    f_end = max(f, f_end)
            # add extract (f start , f end , e start , e end ) to set BP
            phrases = extract(f_start, f_end, e_start, e_end)
            if phrases:
                bp.update(phrases)
    return bp

# %%
srctext = "Michael geht davon aus , dass er im haus bleibt"
trgtext = "Michael assumes that he will stay in the house"
line = "0-0 1-1 2-1 3-1 5-2 6-3 7-6 7-7 8-8 9-4 9-5"
for i in sorted(phrase_extraction(srctext,trgtext,line)):
    print(i)
# Out:
# ((0, 1), 'Michael', 'Michael')
# ((0, 4), 'Michael geht davon aus', 'Michael assumes')
# ((0, 5), 'Michael geht davon aus ,', 'Michael assumes')
# ((0, 6), 'Michael geht davon aus , dass', 'Michael assumes that')
# ((0, 7), 'Michael geht davon aus , dass er', 'Michael assumes that he')
# ((0, 7), 'Michael geht davon aus , dass er', 'Michael assumes that he will')
# ((0, 10), 'Michael geht davon aus , dass er im haus bleibt', 'Michael assumes that he will stay in the house')
# ((1, 4), 'geht davon aus', 'assumes')
# ((1, 5), 'geht davon aus ,', 'assumes')
# ((1, 6), 'geht davon aus , dass', 'assumes that')
# ((1, 7), 'geht davon aus , dass er', 'assumes that he')
# ((1, 7), 'geht davon aus , dass er', 'assumes that he will')
# ((1, 10), 'geht davon aus , dass er im haus bleibt', 'assumes that he will stay in the house')
# ((4, 6), ', dass', 'that')
# ((4, 7), ', dass er', 'that he')
# ((4, 7), ', dass er', 'that he will')
# ((4, 10), ', dass er im haus bleibt', 'that he will stay in the house')
# ((5, 6), 'dass', 'that')
# ((5, 7), 'dass er', 'that he')
# ((5, 7), 'dass er', 'that he will')
# ((5, 10), 'dass er im haus bleibt', 'that he will stay in the house')
# ((6, 7), 'er', 'he')
# ((6, 7), 'er', 'he will')
# ((6, 10), 'er im haus bleibt', 'he will stay in the house')
# ((7, 8), 'im', 'in the')
# ((7, 9), 'im haus', 'in the house')
# ((7, 10), 'im haus bleibt', 'will stay in the house')
# ((8, 9), 'haus', 'house')
# ((9, 10), 'bleibt', 'will stay')

# %%
#srctext = "Michael geht davon aus , dass er im haus bleibt"
#trgtext = "Michael assumes that he will stay in the house"
#line = "0-0 1-1 2-1 3-1 5-2 6-3 7-6 7-7 8-8 9-4 9-5"

srctext = "José , su marido , que era un hombre justo y no quería denunciar públicamente a María , decidió separarse de ella en secreto ."
trgtext = "Her husband Joseph was an honorable man and did not want to disgrace her publicly . So he decided to break the marriage agreement with her secretly ."
line = "0-2 1-0 2-0 3-1 4-1 5-3 6-3 7-4 8-6 9-5 10-7 11-9 12-8 12-10 13-11 13-12 14-14 15-13 16-13 17-15 18-17 18-18 19-19 19-20 19-21 19-22 19-23 20-24 21-25 22-26 23-26 24-27"

#def find_phrases(line):
#    """
#    This is John Sylak-Glassman's pure implementation of DeNero, Bouchard-Cote, and Klein's instructions:
#    "We greedily constructed a phrase alignment from the word alignment by identifying minimal phrase 
#    pairs consistent with the word alignment in each region of the sentence."
#    """
srclen = len(srctext.split())
trglen = len(trgtext.split())
src_dict = {}
trg_dict = {}
for i, word in enumerate(srctext.split()):
    src_dict[i] = word
for i, word in enumerate(trgtext.split()):
    trg_dict[i] = word
f_aligned = set()
e_aligned = set()
line_lst = line.split()
alignment = list()
for pair in line_lst:
    [f, e] = pair.split("-")
    f_aligned.add(int(f))
    e_aligned.add(int(e))
    alignment.append((int(f),int(e)))
alignment = sorted(alignment)

phrase_set = set()
phrase = set()
prev_e = 0
prev_f = 0
for f,e in alignment:
    if abs(e - prev_e) > 1:
        phrase_set.add(frozenset(phrase))
        phrase = set([(e,f)])
    if abs(f - prev_f) > 1:
        phrase_set.add(frozenset(phrase))
        phrase = set([(e,f)])
    else:
        phrase.add((e,f))
    prev_e = e
    prev_f = f
phrase_set.add(frozenset(phrase))
for i in sorted(phrase_set):
    full_phrase = []
    for pair in sorted(i):
        full_phrase.append((trg_dict[pair[0]],src_dict[pair[1]]))
    print(full_phrase)
# Out:
# []
# [('her', 'a'), ('her', 'María'), ('publicly', 'públicamente')]
# [('was', 'que'), ('was', 'era'), ('an', 'un')]
# [('Joseph', 'José')]
# [('honorable', 'justo'), ('man', 'hombre')]
# [('he', 'decidió'), ('decided', 'decidió'), ('to', 'separarse'), ('break', 'separarse'), ('the', 'separarse'), ('marriage', 'separarse'), ('agreement', 'separarse'), ('with', 'de'), ('her', 'ella'), ('secretly', 'en'), ('secretly', 'secreto'), ('.', '.')]
# [('did', 'quería'), ('not', 'no')]
# [('want', 'quería'), ('to', 'denunciar'), ('disgrace', 'denunciar')]
# [('and', 'y')]
# [('.', ',')]
# [('Her', ','), ('Her', 'su'), ('husband', 'marido'), ('husband', ',')]
